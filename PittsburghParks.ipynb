# %%
import pandas as pd
import numpy as np
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
pgh_park_data = pd.read_csv("PittsburghPlayingFields.csv",
                           index_col="id")

pgh_park_data.head(10)
# Out:
#                                              name has_lights  \
# id
# 1914615260                      Arlington Field 1          t
# 1151740179                              Armstrong          f
# 971009139                                 Bandbox          f
# 1581124728                             Banksville          f
# 1052125703                      Banksville School          t
# 491692062                                  Bigbee          f
# 332143201                             Bill Stoltz          t
# 800768920                Brighton Heights Field 1          f
# 742572488                Brighton Heights Field 2          f
# 183023484   Brighton Heights Field 3 - John Merry          f
#
#                                         park              field_usage  \
# id
# 1914615260                    Arlington Park             Diamond Only
# 1151740179                    Armstrong Park  Diamond and Rectangular
# 971009139                       Arsenal Park             Diamond Only
# ...
